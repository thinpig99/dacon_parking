# %% [markdown]
# # **임대주택 단지 내 적정 주차수요 예측 대회**

# %% [markdown]
# **[배경]**
#
# 아파트 단지 내 필요한 주차대수는 ①법정주차대수 ②장래주차수요 중 큰 값에 따라 결정하게되어 있어, 정확한 ②장래주차수요의 산정을 필요로 합니다.<br>
# 현재 ②장래주차수요는 ‘주차원단위’와 ‘건축연면적’을 기초로하여 산출되고 있으며,<br>
# ‘주차원단위’는 신규 건축예정 부지 인근의 유사 단지를 피크 시간대 방문하여 주차된 차량대수를 세는 방법으로 조사하고 있습니다.<br>
# 이 경우 인력조사로 인한 오차발생, 현장조사 시점과 실제 건축시점과의 시간차 등의 문제로 과대 또는 과소 산정의 가능성을 배제할 수 없습니다.<br>
#
# **[주제]**
# 유형별 임대주택 설계 시 단지 내 적정 주차 수요를 예측

# %% [markdown]
# **[평가]**
#
# - 평가산식 : **MAE(Mean Absolute Error)**
# - Public 평가 : 전체 Test 데이터 중 무작위 **33% (50단지)**
# - Private 평가 : 전체 Test 데이터 중 나머지 **67% (100단지)**
#
# **[외부 데이터 및 사전학습 모델]**
#
# - 공공 데이터와 같이 누구나 얻을 수 있고 법적 제약이 없는 **외부 데이터 허용**
# - 사전학습 모델의 경우 **사전학습에 사용된 데이터를 명시**해야함
# - 최종 평가시 외부데이터 및 출처 제출

# %% [markdown]
# # Data Understanding

# %% [markdown]
# **train.csv - 학습용 데이터**
#
# - 단지코드(key)
# - 총세대수
# - 임대건물구분
# - 지역
# - 공급유형
# - 전용면적
# - 전용면적별세대수
# - 공가수: 빈집
# - 신분: ?
# - 임대료보증금
# - 임대료
# - 도보 10분거리 내 지하철역 수(환승노선 수 반영)
# - 도보 10분거리 내 버스정류장 수
# - 단지내주차면수
# - 등록차량수(target)
#
# **age_gender_info.csv - 지역 임대주택 나이별, 성별 인구 분포**
#
# - 지역
# - 10대미만(여자)
# - 10대미만(남자)
# - 20대(여자)
# - 20대(남자)
# - 30대(여자)
# - 30대(남자)
# - 40대(여자)
# - 40대(남자)
# - 50대(여자)
# - 50대(남자)
# - 60대(여자)
# - 60대(남자)
# - 70대(여자)
# - 70대(남자)
# - 80대(여자)
# - 80대(남자)
# - 90대(여자)
# - 90대(남자)
# - 100대(여자)
# - 100대(남자)

# %%
PATH = r'C:\Users\Wyatt\wyatt37\data\parking'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

import warnings
warnings.filterwarnings("ignore")

# %%
age_gender = pd.read_csv(PATH + '\\age_gender_info.csv')
age_gender
# Out:
#          지역  10대미만(여자)  10대미만(남자)   10대(여자)   10대(남자)   20대(여자)   20대(남자)  \
# 0      경상북도   0.030158   0.033195  0.056346  0.061360  0.060096  0.067859
# 1      경상남도   0.027400   0.026902  0.053257  0.055568  0.064920  0.070618
# 2     대전광역시   0.028197   0.029092  0.040490  0.042793  0.060834  0.064247
# 3       경기도   0.038030   0.039507  0.052546  0.053990  0.058484  0.059894
# 4      전라북도   0.028089   0.029065  0.059685  0.060080  0.066262  0.070322
# 5       강원도   0.028888   0.030682  0.051287  0.052712  0.060374  0.063
대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# 0     22830000  189840                           0.0                 2.0
# 1     36048000  249930                           0.0                 2.0
# 2     36048000  249930                           0.0                 2.0
# 3     36048000  249930                           0.0                 2.0
# 4     43497000  296780                           0.0                 2.0
# ...        ...     ...                           ...                 ...
# 1017         -       -                           0.0                 1.0
# 1018   6872000  106400                           0.0                 2.0
# 1019   6872000  106400                           0.0                 2.0
# 1020  13410000  144600                           0.0                 2.0
# 1021  18689000  166500                           0.0                 2.0
#
#       단지내주차면수
# 0       683.0
# 1       683.0
# 2       683.0
# 3       683.0
# 4       683.0
# ...       ...
# 1017    467.0
# 1018    300.0
# 1019    300.0
# 1020    300.0
# 1021    300.0
#
# [1022 rows x 14 columns]

# %%
sub = pd.read_csv(PATH + '\\sample_submission.csv')
sub
# Out:
#       code  num
# 0    C1072    0
# 1    C1128    0
# 2    C1456    0
# 3    C1840    0
# 4    C1332    0
# ..     ...  ...
# 145  C2456    0
# 146  C1266    0
# 147  C2152    0
# 148  C1267    0
# 149  C2189    0
#
# [150 rows x 2 columns]

# %%
age_gender.shape, train.shape, test.shape, sub.shape
# Out:
# ((16, 23), (2952, 15), (1022, 14), (150, 2))

# %% [markdown]
# ## age_gender_info

# %%
ag = age_gender.set_index('지역')

# %%
ag.loc['평균'] = ag.mean()

# %%
plt.figure(figsize=(14, 9))
sns.heatmap((ag*100).round(3),
           annot=True, linewidths=0.01,)

plt.show()

# %%
fig = plt.figure(figsize = (18, 6))
sns.lineplot(data=ag.T, )
plt.title('지역별 세대(양성) 라인 차트')
plt.xticks(rotation=45)
plt.ylim(top=0.13)
plt.show()

# %%
fig = plt.figure(figsize = (18, 6))
sns.lineplot(data=ag.loc[:, ag.columns.str.contains('여자')].T)
plt.title('지역별 세대(여자) 라인 차트')
plt.ylim(top=0.13)
plt.show()

fig = plt.figure(figsize = (18, 6))
sns.lineplot(data=ag.loc[:, ag.columns.str.contains('남자')].T)
plt.title('지역별 세대(남자) 라인 차트')
plt.ylim(top=0.13)
plt.show()

# %%
fig = plt.figure(figsize=(22, 18))
plt.xticks(rotation=90)
for i, n in enumerate(list(ag.index)):
    plt.subplot(5, 5, i+1)
    plt.subplots_adjust(hspace=1.0)
    plt.title("{} 인구비중".format(n))
    sns.barplot(data=ag.loc[ag.index == n])
    plt.xticks(rotation=90)

# %% [markdown]
# ## train

# %% [markdown]
# ### NA Values

# %% [markdown]
# 언뜻 보기에 여러개의 테이블이 join 되어 있는 것으로 보입니다. 데이터를 심도 있게 살펴보아야 정보 손실을 줄이면서 학습에 활용할 수 있을 것 같습니다.

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(train.isnull().T, cbar=False)
plt.show()

# %% [markdown]
# - 신분, 임대보증금, 임대료, 지하철역, 버스정류장 에서 결측치가 있습니다.
# - 신분, 임대보증금, 임대료에서의 결측치는 등장하는 row가 동일해 보입니다.

# %% [markdown]
# #### NA of Subway

# %%
train.loc[train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].isnull()].sample(5)
# Out:
#        단지코드  총세대수 임대건물구분     지역       공급유형   전용면적  전용면적별세대수   공가수   신분  \
# 2318  C1649   575    아파트   경상남도  공공임대(10년)  84.98        82  15.0   일반
# 211   C1704   639     상가  대전광역시       임대상가  31.84         1  34.0  NaN
# 2317  C1649   575    아파트   경상남도  공공임대(10년)  84.96       289  15.0   일반
# 220   C2258   965     상가  대전광역시       임대상가  19.31         1  13.0  NaN
# 641   C2644   779    아파트   충청남도  공공임대(50년)  37.67       298   7.0   일반
#
#          임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# 2318  57000000  462000                           NaN                 NaN
# 211        NaN     NaN                           NaN                 7.0
# 2317  57000000  462000                           NaN                 NaN
# 220        NaN     NaN                           NaN                 3.0
# 641   11879000  161250                           NaN                12.0
#
#       단지내주차면수  등록차량수
# 2318   1066.0    855
# 211     176.0    131
# 2317   1066.0    855
# 220     197.0     78
# 641     198.0    177

# %%
print('전체 단지 수: ', train['단지코드'].nunique())
print('지하철 결측치 단지 수: ', train.loc[train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].isnull()]['단지코드'].nunique())
print('지하철 결측치 단지: ', train.loc[train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].isnull()]['단지코드'].unique())
print('지하철 결측치 단지 지역: ', train.loc[train['도보 10분거리 내 지하철역 수(환승노선 수 반영)'].isnull()]['지역'].unique())
# Out:
# 전체 단지 수:  423
# 지하철 결측치 단지 수:  20
# 지하철 결측치 단지:  ['C1312' 'C1874' 'C1424' 'C2100' 'C2520' 'C1616' 'C1704' 'C2258' 'C1068'
#  'C1983' 'C2216' 'C2644' 'C1005' 'C1004' 'C1875' 'C2156' 'C1175' 'C2583'
#  'C1649' 'C1350']
# 지하철 결측치 단지 지역:  ['충청남도' '대전광역시' '경상남도']

# %% [markdown]
# - 지하철 결측값은 총 20개의 단지에서 발생했습니다.
# - 지하철 결측값은 충남, 대전, 경남에서만 발생하였습니다.
# - 해당 지역에 지하철이 없더라도 0.0 으로 값이 채워져 있는 단지가 있습니다.
# - 따라서 패턴이 없는 단순 결측치로 보입니다.
# - 그러나 충남 북부나, 경남 남부 같은 경우는 지하철이 있는 도시가 있습니다. 마찬가지로 대전은 대전지하철이 있습니다. 결측치를 채우는 것을 고심해봐야 합니다.

# %% [markdown]
# #### NA of BusStop

# %%
train.loc[train['도보 10분거리 내 버스정류장 수'].isnull()]
# Out:
#        단지코드  총세대수 임대건물구분    지역       공급유형   전용면적  전용면적별세대수   공가수  신분  \
# 2315  C1649   575    아파트  경상남도  공공임대(10년)  74.97        80  15.0  일반
# 2316  C1649   575    아파트  경상남도  공공임대(10년)  84.95       124  15.0  일반
# 2317  C1649   575    아파트  경상남도  공공임대(10년)  84.96       289  15.0  일반
# 2318  C1649   575    아파트  경상남도  공공임대(10년)  84.98        82  15.0  일반
#
#          임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# 2315  46000000  456000                           NaN                 NaN
# 2316  57000000  462000                           NaN                 NaN
# 2317  57000000  462000                           NaN                 NaN
# 2318  57000000  462000                           NaN                 NaN
#
#       단지내주차면수  등록차량수
# 2315   1066.0    855
# 2316   1066.0    855
# 2317   1066.0    855
# 2318   1066.0    855

# %%
train.loc[train['도보 10분거리 내 버스정류장 수'].isnull()]['지역'].unique()
# Out:
# array(['경상남도'], dtype=object)

# %% [markdown]
# - 버스 정류장 데이터가 없는 단지는 단 하나 뿐입니다.
# - 이정도면 직접 정보를 찾아서 넣어줄 수도 있을 것 같습니다.

# %% [markdown]
# #### NA of Shop(상가)

# %%
train.loc[train['단지코드'] == 'C1004'].head()
# Out:
#       단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수  공가수     신분    임대보증금  \
# 764  C1004   521    아파트  충청남도  영구임대  39.30       240  3.0  3차탈락자  4682000
# 765  C1004   521    아파트  충청남도  영구임대  39.69       264  3.0  3차탈락자  4728000
# 766  C1004   521     상가  충청남도  임대상가  19.00         1  3.0    NaN      NaN
# 767  C1004   521     상가  충청남도  임대상가  14.10         1  3.0    NaN      NaN
# 768  C1004   521     상가  충청남도  임대상가  19.31         1  3.0    NaN      NaN
#
#         임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 764  104180                           NaN                 2.0    152.0     93
# 765  105210                           NaN                 2.0    152.0     93
# 766     NaN                           NaN                 2.0    152.0     93
# 767     NaN                           NaN                 2.0    152.0     93
# 768     NaN                           NaN                 2.0    152.0     93

# %%
len(train.loc[train['임대건물구분'] == '상가'])
# Out:
# 562

# %%
train.loc[train['임대건물구분'] == '상가'].isnull().sum().to_frame()
# Out:
#                                 0
# 단지코드                            0
# 총세대수                            0
# 임대건물구분                          0
# 지역                              0
# 공급유형                            0
# 전용면적                            0
# 전용면적별세대수                        0
# 공가수                             0
# 신분                            562
# 임대보증금                         562
# 임대료                           562
# 도보 10분거리 내 지하철역 수(환승노선 수 반영)  127
# 도보 10분거리 내 버스정류장 수              0
# 단지내주차면수                         0
# 등록차량수                           0

# %% [markdown]
# - 아파트 단지에 상가가 있는 경우가 있습니다.
# - 상가는 신분, 임대보증금, 임대료가 전부 결측치입니다.

# %%
print('전체 단지 수: ', train['단지코드'].nunique())
print('상가 보유 단지 수: ', train.loc[train['임대건물구분'] == '상가']['단지코드'].nunique())
print('상가 보유 단지: ', train.loc[train['임대건물구분'] == '상가']['단지코드'].unique())
print('상가 보유 단지 지역: ', train.loc[train['임대건물구분'] == '상가']['지역'].unique())
# Out:
# 전체 단지 수:  423
# 상가 보유 단지 수:  33
# 상가 보유 단지:  ['C1925' 'C1874' 'C2416' 'C2621' 'C1616' 'C1704' 'C2258' 'C2038' 'C1859'
#  'C1722' 'C2190' 'C1476' 'C1983' 'C2135' 'C2034' 'C1109' 'C2289' 'C2597'
#  'C2310' 'C2132' 'C1439' 'C1899' 'C1056' 'C2644' 'C1206' 'C1775' 'C1790'
#  'C2109' 'C1698' 'C1004' 'C1875' 'C2212' 'C2571']
# 상가 보유 단지 지역:  ['강원도' '충청남도' '경상남도' '대전광역시' '부산광역시' '제주특별자치도']

# %% [markdown]
# - 총 33개 단지에서 상가를 보유하고 있습니다.
# - 지역도 매우 다양합니다.

# %% [markdown]
# ### 전용면적

# %%
train.loc[train['단지코드'] == 'C2612']
# Out:
#        단지코드  총세대수 임대건물구분       지역  공급유형   전용면적  전용면적별세대수   공가수  신분     임대보증금  \
# 2463  C2612  1684    아파트  세종특별자치시  국민임대  29.71       628  27.0  일반   9800000
# 2464  C2612  1684    아파트  세종특별자치시  국민임대  29.71        54  27.0  일반   9800000
# 2465  C2612  1684    아파트  세종특별자치시  국민임대  36.61       620  27.0  일반  12800000
# 2466  C2612  1684    아파트  세종특별자치시  국민임대  46.41       382  27.0  일반  27500000
#
#          임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 2463  154000                           0.0                 2.0   1689.0   1832
# 2464  154000                           0.0                 2.0   1689.0   1832
# 2465  197000                           0.0                 2.0   1689.0   1832
# 2466  257000                           0.0                 2.0   1689.0   1832

# %% [markdown]
# - 전용면적이 동일한 데이터가 있어서 알아보니 타입이 다른 것입니다.

# %%
from IPython.display import Image
Image(url='qqq.jpg', width=500)
# Out:
# <img src="qqq.jpg" width="500"/>

# %% [markdown]
# LH 청약센터 홈페이지에서 찾은 C2612 아파트의 임대 공고 정보입니다. 전용면적과 전용면적별세대수가 정확히 일치합니다.<br>
# 즉, 전용면적이 같더라도 타입이 다르고, 전용면적별세대수가 별도로 존재하는 것입니다.

# %%
train.groupby(['단지코드']).nunique().describe()
# Out:
#         총세대수      임대건물구분     지역        공급유형        전용면적    전용면적별세대수    공가수  \
# count  423.0  423.000000  423.0  423.000000  423.000000  423.000000  423.0
# mean     1.0    1.078014    1.0    1.153664    4.486998    5.271868    1.0
# std      0.0    0.268511    0.0    0.398492    3.191992    2.526511    0.0
# min      1.0    1.000000    1.0    1.000000    1.000000    1.000000    1.0
# 25%      1.0    1.000000    1.0    1.000000    3.000000    3.000000    1.0
# 50%      1.0    1.000000    1.0    1.000000    4.000000    5.000000    1.0
# 75%      1.0    1.000000    1.0    1.000000    5.000000    6.000000    1.0
# max      1.0    2.000000    1.0    3.000000   29.000000   18.000000    1.0
#
#                신분       임대보증금         임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# count  423.000000  423.000000  423.000000                    423.000000
# mean     1.125296    2.938534    2.966903                      0.952719
# std      0.384410    1.019248    1.025200                      0.212491
# min      1.000000    1.000000    1.000000                      0.000000
# 25%      1.000000    2.000000    2.000000                      1.000000
# 50%      1.000000    3.000000    3.000000                      1.000000
# 75%      1.000000    3.000000    4.000000                      1.000000
# max      3.000000    7.000000    7.000000                      1.000000
#
#        도보 10분거리 내 버스정류장 수     단지내주차면수  등록차량수
# count          423.000000  423.000000  423.0
# mean             0.997636    1.002364    1.0
# std              0.048622    0.048622    0.0
# min              0.000000    1.000000    1.0
# 25%              1.000000    1.000000    1.0
# 50%              1.000000    1.000000    1.0
# 75%              1.000000    1.000000    1.0
# max              1.000000    2.000000    1.0

# %%
train.loc[train['단지코드'] == 'C1056']
# Out:
#       단지코드  총세대수 임대건물구분       지역  공급유형   전용면적  전용면적별세대수  공가수     신분    임대보증금  \
# 628  C1056   410    아파트  제주특별자치도  영구임대  26.34       200  0.0  3차탈락자  3138000
# 629  C1056   410    아파트  제주특별자치도  영구임대  30.48       200  0.0  3차탈락자  3631000
# 630  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 631  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 632  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 633  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 634  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 635  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 636  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 637  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 638  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
# 639  C1056   410     상가  제주특별자치도  임대상가  31.84         1  0.0    NaN      NaN
#
#        임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 628  69820                           0.0                10.0    113.0    125
# 629  80800                           0.0                10.0    113.0    125
# 630    NaN                           0.0                10.0    113.0    125
# 631    NaN                           0.0                10.0    113.0    125
# 632    NaN                           0.0                10.0    113.0    125
# 633    NaN                           0.0                10.0    113.0    125
# 634    NaN                           0.0                10.0    113.0    125
# 635    NaN                           0.0                10.0    113.0    125
# 636    NaN                           0.0                10.0    113.0    125
# 637    NaN                           0.0                10.0    113.0    125
# 638    NaN                           0.0                10.0    113.0    125
# 639    NaN                           0.0                10.0    113.0    125

# %% [markdown]
# 도대체 데이터가 왜 이렇게 생겼을까..?

# %%
train.groupby(['단지코드']).nunique().describe()
# Out:
#         총세대수      임대건물구분     지역        공급유형        전용면적    전용면적별세대수    공가수  \
# count  423.0  423.000000  423.0  423.000000  423.000000  423.000000  423.0
# mean     1.0    1.078014    1.0    1.153664    4.486998    5.271868    1.0
# std      0.0    0.268511    0.0    0.398492    3.191992    2.526511    0.0
# min      1.0    1.000000    1.0    1.000000    1.000000    1.000000    1.0
# 25%      1.0    1.000000    1.0    1.000000    3.000000    3.000000    1.0
# 50%      1.0    1.000000    1.0    1.000000    4.000000    5.000000    1.0
# 75%      1.0    1.000000    1.0    1.000000    5.000000    6.000000    1.0
# max      1.0    2.000000    1.0    3.000000   29.000000   18.000000    1.0
#
#                신분       임대보증금         임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# count  423.000000  423.000000  423.000000                    423.000000
# mean     1.125296    2.938534    2.966903                      0.952719
# std      0.384410    1.019248    1.025200                      0.212491
# min      1.000000    1.000000    1.000000                      0.000000
# 25%      1.000000    2.000000    2.000000                      1.000000
# 50%      1.000000    3.000000    3.000000                      1.000000
# 75%      1.000000    3.000000    4.000000                      1.000000
# max      3.000000    7.000000    7.000000                      1.000000
#
#        도보 10분거리 내 버스정류장 수     단지내주차면수  등록차량수
# count          423.000000  423.000000  423.0
# mean             0.997636    1.002364    1.0
# std              0.048622    0.048622    0.0
# min              0.000000    1.000000    1.0
# 25%              1.000000    1.000000    1.0
# 50%              1.000000    1.000000    1.0
# 75%              1.000000    1.000000    1.0
# max              1.000000    2.000000    1.0

# %%
train.groupby(['지역']).nunique()
# Out:
#          단지코드  총세대수  임대건물구분  공급유형  전용면적  전용면적별세대수  공가수  신분  임대보증금  임대료  \
# 지역
# 강원도        37    36       2     6    83        91   18   7     98  105
# 경기도        88    87       1     4   212       239   30   9    243  250
# 경상남도       55    55       2     6   167       153   25   7    141  140
# 경상북도       22    22       1     3    57        74   15   4     63   63
# 광주광역시      24    23       1     4    65       100   16   8     54   58
# 대구광역시      18    18       1     4    57        70   16   5     50   50
# 대전광역시      25    25       2     9   107       106   15   5     65   69
# 부산광역시      25    25       2     6   129        88   17   7     51   50
# 서울특별시       8     8       1     7    41        50    7   3     38   33
# 세종특별자치시     4     4       1     2    33        39    4   1     10   15
# 울산광역시       8     8       1     3    20        28    8   3     19   19
# 전라남도       25    25       1     4    64        94   13   6     68   68
# 전라북도       21    21       1     4    56        74   14   4     51   52
# 제주특별자치도    14    14       2     5    46        53   10   4     36   38
# 충청남도       19    19       2     4    86        61   13   4     51   52
# 충청북도       30    30       1     4    85        97   18   5     79   76
#
#          도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 지역
# 강원도                                 1                   7       35     37
# 경기도                                 3                  14       85     86
# 경상남도                                1                  10       50     54
# 경상북도                                1                   8       22     22
# 광주광역시                               1                   7       24     24
# 대구광역시                               3                   8       18     18
# 대전광역시                               2                   9       25     24
# 부산광역시                               4                   5       25     25
# 서울특별시                               2                   3        7      6
# 세종특별자치시                             1                   2        4      4
# 울산광역시                               1                   4        8      8
# 전라남도                                1                   6       24     25
# 전라북도                                1                   5       21     21
# 제주특별자치도                             1                   8       14     14
# 충청남도                                1                   6       19     19
# 충청북도                                1                   6       30     29

# %%
train.loc[train['단지코드'] == 'C2612'][['단지코드', '지역', '전용면적', '전용면적별세대수']]
# Out:
#        단지코드       지역   전용면적  전용면적별세대수
# 2463  C2612  세종특별자치시  29.71       628
# 2464  C2612  세종특별자치시  29.71        54
# 2465  C2612  세종특별자치시  36.61       620
# 2466  C2612  세종특별자치시  46.41       382

# %%
train.loc[train['지역'] == '강원도']
# Out:
#        단지코드  총세대수 임대건물구분   지역  공급유형   전용면적  전용면적별세대수   공가수  신분     임대보증금  \
# 67    C2073   361    아파트  강원도  국민임대  39.63        94  13.0  일반  10813000
# 68    C2073   361    아파트  강원도  국민임대  39.63        74  13.0  일반  10813000
# 69    C2073   361    아파트  강원도  국민임대  46.90        97  13.0  일반  16821000
# 70    C2073   361    아파트  강원도  국민임대  46.90        46  13.0  일반  16821000
# 71    C2073   361    아파트  강원도  국민임대  46.96        10  13.0  일반  16821000
# ...     ...   ...    ...  ...   ...    ...       ...   ...  ..       ...
# 2947  C2532   239    아파트  강원도  국민임대  49.20        19   7.0  일반  11346000
# 2948  C2532   239    아파트  강원도  국민임대  51.08        34   7.0  일반  14005000
# 2949  C2532   239    아파트  강원도  국민임대  51.73        34   7.0  일반  14005000
# 2950  C2532   239    아파트  강원도  국민임대  51.96       114   7.0  일반  14005000
# 2951  C2532   239    아파트  강원도  국민임대  54.95        19   7.0  일반  14830000
#
#          임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  단지내주차면수  등록차량수
# 67    144180                           0.0                 5.0    288.0    301
# 68    144180                           0.0                 5.0    288.0    301
# 69    205460                           0.0                 5.0    288.0    301
# 70    205460                           0.0                 5.0    288.0    301
# 71    205460                           0.0                 5.0    288.0    301
# ...      ...                           ...                 ...      ...    ...
# 2947  116090                           0.0                 1.0    171.0    146
# 2948  142310                           0.0                 1.0    171.0    146
# 2949  142310                           0.0                 1.0    171.0    146
# 2950  142310                           0.0                 1.0    171.0    146
# 2951  151030                           0.0                 1.0    171.0    146
#
# [187 rows x 15 columns]
